# %% [markdown]
# # 03 · DIN Attention Visualization + Ablation
#
# **Scheduled:** Week 3, Day 18–20 + Week 4, Day 24
#
# ## Goals
# 1. Visualize attention heatmaps for 5 representative users (hist × target).
# 2. Ablation: attention vs sum pooling — quantify the lift on NDCG@10.
# 3. Hypothesis check: does attention concentrate on in-genre items?
